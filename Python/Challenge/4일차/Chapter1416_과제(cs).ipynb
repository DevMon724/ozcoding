# %% [markdown]
# 컴퓨터 기초 지식을 의미하는 CS(Computer science)는<br>
# 코딩 테스트와 함께 기술 면접에서 지원자에게 필수적으로 요구합니다.<br>
#
# 수업 내용 중 기술 면접에 자주 나오는 질문 3가지와 기본적으로 알아야 할 내용 과제로 선정했습니다.<br>
#
# 관련 내용에 대해서는 구글링 또는 관련 서적을 통해 상세히 공부하시고<br>
# 답변은 최대한 핵심만 담아 간결하게 작성해주세요<br>
#
# 기술 블로그를 운영 중이신 경우<br>
# 답변 내용을 기술 블로그에 작성하신 후 링크를 답변에 남겨주셔도 됩니다.<br>

# %% [markdown]
# -----

# %% [markdown]
# [문제1]
#
# 파이썬 2.7 버전과 파이썬 3에서 range 차이를 설명해주세요

# %% [markdown]
# 파이썬 2.7에서는 range는 list타입으로 생성이 되고, 3에서는 range가 2.7에서의 xrange기능으로 통합되었다.
# range는 list의 사이즈가 클수록 점점 메모리 사용량이 많아진다. 반면 xrange는 데이터값을 한번에 로드하는게 아니라
# 해당 값에 접근할 때마다 값을 로딩하는 방식이다. 그래서 list에서 자주 쓰던 여러 함수들 (slice, operand)등을 사용하지 못하지만
# for문 같은 순차적 접근이나 index를 이용한 접근 위주의 용도로 사용할 때는 xrange()를 사용하는 게 효과적.

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# Python의 얕은 복사와 깊은 복사에 대해서 설명하세요

# %%
Python의 얕은 복사와 깊은 복사에 대해서 설명하세요

얕은 복사는 변수명은 다르지만 그 변수들이 같은 곳을 참조하고 있는 것이다. 하나의 객체를 선언하고 또다른 객체에 먼저 선언한 객체를 참조하도록 했을때 복사가 된 것처럼 보이지만
실제로는 같은 메모리 주소를 참조만 하고 있는 것이기 때문에 먼저 선언한 객체의 값이 바뀌면 해당 객체의 값도 똑같이 바뀌게 된다.

깊은 복사는 리스트 내부 리스트, 딕셔너리 내부 리스트 등 내부에 있는 객체 모두를 새롭게 만들어 주는 작업을 함. 한마디로 모든 것을 다 복사하여 독립적인 공간에 메모리 할당을 함.
깊은 복사를 하기 위해서는 copy 모듈을 import하고 deepcody()함수를 사용하면 됨.
