# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# Chapter17 ~ 20의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후 ▷ 버튼을 클릭해 코드를 실행해보세요<br>

# %% [markdown]
# [문제1]
#
# print_even 리스트 내에 있는 값 중 짝수만 화면에 출력되도록 print_score 함수를 생성 후 결과값을 출력해주세요
#
# print_even ([1, 3, 2, 10, 12, 11, 15])

# %%
print_even = [1,3,2,10,12,11,15]
def print_score(score) :
    for x in score :
        if x % 2 == 0 :
            print(x)

print_score(print_even)
# Out:
# 2
# 10
# 12

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# 비어있는 오즈 (oz) 클래스를 "정의" 해보세요.

# %%
class oz :
    pass

# %% [markdown]
# ---

# %% [markdown]
# [문제3]
#
# 오즈(oz) 클래스의 인스턴스를 "생성" 하고 이를 coding 변수로 할당해보세요.

# %%
class oz() :
    pass
coding = oz()

# %% [markdown]
# ---

# %% [markdown]
# [문제4]
#
# 오즈(oz) 클래스에 "클래스 정복"을 출력하는 기본 생성자를 추가해주세요

# %%
class oz() :
    def __init__(self) :

        print("클래스 정복")

coding = oz()
# Out:
# 클래스 정복

# %% [markdown]
# ---

# %% [markdown]
# [문제5]
#
# 오즈 (oz) 클래스에 (이름, 나이, 코딩레벨)을 받는 생성자를 추가해주세요
#
# coding = oz("김코", 30, "A")

# %%
class oz : 
    def __init__(self, name, age, coding_level) -> None:
        self.name = name
        self.age = age
        self.coding_level = coding_level
coding = oz("김코", 30, "A")

# %% [markdown]
# ---

# %% [markdown]
# [문제6]
#
# 5번 문제에서 생성한 인스턴스의 이름, 나이, 성별을 출력해주세요.
# 인스턴스 변수에 접근하여 값을 출력하면 됩니다  : )
#
# 출력 결과
# 이름 : 김코
# 나이 : 30
# 코딩레벨 : A

# %%
print("이름 : ", coding.name)
print("나이 : ", coding.age)
print("코딩레벨 : ", coding.coding_level)

# %% [markdown]
# ---

# %% [markdown]
# [뮨제7]
#
# 오즈 (oz) 클래스에서 이름, 나이, 성별을 출력하는 who() 메소드를 추가하고 who()메소드를 이용해 아래 출력 결과를 만들어주세요
#
#
# 출력 결과 : 이름: 김코, 나이: 30, 코딩레벨: A

# %%
class oz : 
    def __init__(self, name, age, coding_level) -> None:
        self.name = name
        self.age = age
        self.coding_level = coding_level

    def who(self) :
        return f"이름:{self.name}, 나이:{self.age}, 코딩레벨:{self.coding_level}"
coding = oz("김코", 30, "A")
print(coding.who())
# Out:
# 이름:김코, 나이:30, 코딩레벨:A

# %% [markdown]
# #### 리팩토링 과제
#
# Day4에서 만든 "붕어빵 자동 판매 시스템"은 절차적 코드로 구현되어있습니다.
#
# Day5에서 배운 함수, 클래스 개념을 적용시켜 객체지향적으로 리팩토링을 진행해주세요

# %%
# 리팩토링 과제 힌트
# 구조는 아래와 같습니다.
class BungeoppangShop:
    def __init__(self):
    
        
    def check_stock(self):
    

    def process_order(self, bread_type, bread_count):


    def admin_mode(self):

    def calculate_total_sales(self):

def main():

if __name__ == "__main__":
    main()

# %% [markdown]
# 과제_1: BungeoppangShop 클래스 만들기
#
# - __init__: 초기 재고, 가격, 판매량을 설정합니다.
# - check_stock: 현재 재고를 출력합니다.
# - process_order: 주문을 처리하고 재고를 업데이트합니다.
# - admin_mode: 관리자 모드에서 재고를 추가합니다.
# - calculate_total_sales: 총 매출을 계산하고 출력합니다.

# %%
class BungeoppangShop:
    def __init__(self):
        pass
    def check_stock(self) :
        pass
    def process_order(self, bread_type, bread_count) :
        pass
    def admin_mode(self, bread_type, additional_stock) :
        pass
    def calculate_total_sales(self) :
        pass

# %% [markdown]
# [과제 2: 초기화 메서드 __init__]
#
# 목표: __init__ 메서드를 구현하여 붕어빵 가게의 초기 재고, 가격, 판매량을 설정합니다.
#
# 설명: self.stock, self.prices, self.sales 딕셔너리를 초기화하세요.
# - stock
#     - "팥붕어빵": 10
#     - "슈크림붕어빵": 8
#     - "초코붕어빵": 5
#
# - prices
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - sales
#     - "팥붕어빵": 0,
#     - "슈크림붕어빵": 0,
#     - "초코붕어빵": 0

# %%
def __init__(self):
    self.stock = {"팥붕어빵" : 10, "슈크림붕어빵" : 8, "초코붕어빵" : 5}
    self.prices = {"팥붕어빵" : 1000, "슈크림붕어빵" : 1200, "초코붕어빵" : 1500}
    self.sales = {"팥붕어빵" : 0, "슈크림붕어빵" : 0, "초코붕어빵" : 0}

# %% [markdown]
# [과제 3: 재고 확인 메서드 check_stock]
#
# 목표: check_stock 함수를 구현하여 현재 붕어빵 재고를 출력합니다.
#
# 설명: self.stock 딕셔너리를 순회하며 각 붕어빵의 종류와 재고를 출력하세요.

# %%
def check_stock(self):
    print(f'현재 재고는 팥{self.stock["팥붕어빵"]}개, 슈크림{self.stock["슈크림붕어빵"]}개, 초코{self.stock["초코붕어빵"]}개 입니다.')

# %% [markdown]
# [과제 4: 주문 처리 메서드 process_order]
#
# 목표: process_order 함수를 구현하여 손님의 주문을 처리하고 재고를 업데이트합니다.
#
# 설명: bread_type과 bread_count를 매개변수로 받아, 재고를 확인하고 충분한 경우 재고를 감소시키고 판매량을 증가시킵니다. 재고가 부족하거나 잘못된 붕어빵 종류인 경우 적절한 메시지를 출력하세요.

# %%
def process_order(self, bread_type, bread_count):
    repeat = True
    while repeat == True :
        #숫자로 입력된 키값을 이름으로 변환
        if bread_type == '1' :
            bread_type = '팥붕어빵'
        if bread_type == '2' :
            bread_type = '슈크림붕어빵'
        if bread_type == '3' :
            bread_type = '초코붕어빵'

        #재고량이 충분한지 확인 후 처리
        if self.stock[bread_type] >= int(bread_count) :
            self.stock[bread_type] -= int(bread_count)
            self.sales[bread_type] += int(bread_count)
            print(f'{bread_type} {bread_count}개를 판매했습니다.')
            a.check_stock()

            #한 번의 주문이 끝난 후 종료할 것인지 물음.
            question = input('종료하시겠습니까? (예/아니오) : ')
            if question == "예" :
                print("사용을 종료합니다.")
                repeat = False 
            else : 
                a.process_order(input('구매할 붕어빵 종류를 선택해주세요. (1.팥 2.슈크림 3.초코)'), input('구매할 붕어빵 개수를 입력하세요.')) #이 재호출 부분을 더 깔끔하게 구현할 수 있을까?...
                break #바로 위에서 함수를 재호출 하므로 break를 해주지 않으면 이전에 호출했던 함수의 반복과 새로 호출된 함수가 겹쳐 충돌.(이것 때문에 오류 찾느라 고생... 함수 반복할 때 주의하자!)

        #재고가 없을 경우 사용자에게 알린 후 판매하지 않음.
        else :
            print(f'{bread_type}의 재고가 부족합니다.')
            
            question = input('종료하시겠습니까? (예/아니오) : ')
            if question == "예" :
                print("사용을 종료합니다.")
                repeat = False
            else : 
                a.process_order(input('구매할 붕어빵 종류를 선택해주세요. (1.팥 2.슈크림 3.초코)'), input('구매할 붕어빵 개수를 입력하세요.'))
                break

# %% [markdown]
# [과제 5: 관리자 모드 메서드 admin_mode]
#
# 목표: admin_mode 메서드를 구현하여 관리자 모드에서 재고를 추가할 수 있도록 합니다.
#
# 설명: bread_type과 additional_stock을 입력받아 재고를 추가합니다. 잘못된 입력 값이 들어온 경우 적절한 메시지를 출력하세요.

# %%
def admin_mode(self, bread_type, additional_stock):
    repeat = True
    while repeat == True :
        #숫자로 입력된 키값을 이름으로 변환
        if bread_type == '1' :
            bread_type = '팥붕어빵'
        if bread_type == '2' :
            bread_type = '슈크림붕어빵'
        if bread_type == '3' :
            bread_type = '초코붕어빵'

        #재고량에 붕어빵 추가 처리
        self.stock[bread_type] += int(additional_stock)
        print(f'{bread_type} {additional_stock}개를 추가했습니다.')
        a.check_stock()

        #재고 추가가 끝난 후 종료할 것인지 물음.
        question = input('관리자 모드를 종료하시겠습니까? (예/아니오) : ')
        if question == "예" :
            print("사용을 종료합니다.")
            repeat = False
        else : 
            a.admin_mode(input('추가할 붕어빵 종류를 선택해주세요. (1.팥 2.슈크림 3.초코)'), input('추가할 붕어빵 개수를 입력하세요.'))
            break

# %% [markdown]
# [과제 6: 매출 계산 메서드 calculate_total_sales]
#
# 목표: calculate_total_sales 메서드를 구현하여 총 매출을 계산하고 출력합니다.
#
# 설명: self.sales와 self.prices를 사용하여 총 매출을 계산하고 출력하세요.

# %%
def calculate_total_sales(self):
    #사용할 일이 많아 따로 간단한 변수에 선언해줌.
    c_팥 = self.sales["팥붕어빵"] 
    c_슈 = self.sales["슈크림붕어빵"]
    c_초 = self.sales["초코붕어빵"] 

    print(f'총 판매량은 팥{c_팥}개, 슈크림{c_슈}개, 초코{c_초}개 입니다.')
    print(f'팥붕어빵의 판매량은 {c_팥*self.prices["팥붕어빵"]}')
    print(f'슈크림붕어빵의 판매량은 {c_슈*self.prices["슈크림붕어빵"]}')
    print(f'초코붕어빵의 판매량은 {c_초*self.prices["초코붕어빵"]}')
    print(f'총 판매액은 {c_팥*self.prices["팥붕어빵"] + c_슈*self.prices["슈크림붕어빵"] + c_초*self.prices["초코붕어빵"]}원 입니다.')

# %% [markdown]
# [과제 8: 메인 함수 main]
#
# 목표: main 함수를 작성하여 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - BungeoppangShop 객체를 생성합니다.
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "주문" 모드에서는 손님의 주문을 처리하고, "관리자" 모드에서는 재고를 추가할 수 있습니다.
# - 프로그램이 종료될 때 총 매출을 계산하고 데이터를 저장합니다.

# %%
a = BungeoppangShop() #클래스 선언(처음 클래스를 main함수 안에 선언했었는데 코드가 실행은 됐지만 정상적으로 기능이 작동하지 않았다... 이유는 알아보자.. 아마 전역변수로써 존재하지 않아 다른 함수에서 참조하지 못한듯?)

def main():

    a.__init__() #초기화
    a.check_stock() #현재 재고량 확인

    repeat = True
    while repeat == True :
        mode = input('모드를 선택하세요. (1.주문 2.관리자 3.종료)') #모드 선택
        if mode == '1' :
            #사용자가 종료할때까지 반복 주문(반복 루프는 어디서 실행하는 것이 좋을까 고민... 함수를 호출하는 곳보다는 함수 내에서 기능을 구현하는 것이 코드도 깔끔하고 모듈화에 적합한 것 같음...)
            a.process_order(input('구매할 붕어빵 종류를 선택해주세요. (1.팥 2.슈크림 3.초코)'), input('구매할 붕어빵 개수를 입력하세요.')) #주문처리
        elif mode == '2' :
            a.admin_mode(input('추가할 붕어빵 종류를 선택해주세요. (1.팥 2.슈크림 3.초코)'), input('추가할 붕어빵 개수를 입력하세요.'))
        elif mode == '3' :
            a.calculate_total_sales()
            repeat = False
            break   

if __name__ == "__main__":
    main()
